# %% [markdown]
# # Python for Data Analysis Lightning Tutorials
# ## Pandas Cookbook Series
#
# **Python for Data Analysis Lightning Tutorials** is a series of tutorials in Data Analysis, Statistics, and Graphics using Python. The **Pandas Cookbook** series of tutorials provides recipes for common tasks and moves on to more advanced topics in statistics and time series analysis.
#
# <i>Created by Alfred Essa</i>, Apr 27th, 2014
#
# Note: IPython Notebook and Data files can be found at my Github Site: http://github/alfredessa

# %% [markdown]
# ### 4.1 Introduction

# %% [markdown]
# In this tutorial we learn to apply Python slicing operations to a Pandas DataFrame object.

# %% [markdown]
# ### 4.11 Load Libraries

# %%
# load pandas and numpy
import pandas as pd
import numpy as np

# %%
# ipython magic for inline plots
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### 4.12 Create a Sample DataFrame Object

# %%
# we want to a create a dataframe that has dates as rows and cities as columns, 
# the cells will be temperatures


# first let's define a date range, the first two months of 2014

days = pd.date_range('2014-01-01', '2014-02-28', freq = 'D')

# %%
# then we will create a tuple defining the dimensions of our table (59 x 5)

# %%
dim = (59,5)

# %%
# define the data frame
df = pd.DataFrame(np.random.randint(-20,40,dim), index=days, columns=['Madrid','Boston','Tokyo','Shanghai','Kolkata'])

# %%
# check the values
df.tail()
# Out:
#             Madrid  Boston  Tokyo  Shanghai  Kolkata
# 2014-02-24      -4      20      8        -9       16
# 2014-02-25       8      10      8         5       39
# 2014-02-26      29      20     36        29        9
# 2014-02-27      35      14    -19       -13      -19
# 2014-02-28      25      13      7        -2      -16

# %% [markdown]
# ### 4.13 Apply various slices using .ix method

# %%
# range of rows and range of columns 
df.ix[3:6, 'Madrid': 'Tokyo']
# Out:
#             Madrid  Boston  Tokyo
# 2014-01-04      27      -1     33
# 2014-01-05      10      26    -16
# 2014-01-06     -20      36    -17

# %%
# specific rows and specific columns
df.ix[[3,20,49], ['Boston', 'Shanghai']]
# Out:
#             Boston  Shanghai
# 2014-01-04      -1       -20
# 2014-01-21       8        15
# 2014-02-19      12        27

# %%
# specific rows and all columns
df.ix[[3,9,11,13], :]
# Out:
#             Madrid  Boston  Tokyo  Shanghai  Kolkata
# 2014-01-04      27      -1     33       -20        1
# 2014-01-10     -12      27     24         7      -13
# 2014-01-12      28      13     29        10       12
# 2014-01-14      22      27     39       -14       35

# %%
# all rows and range of columns
df.ix[ :, 'Madrid': 'Tokyo']
# Out:
#             Madrid  Boston  Tokyo
# 2014-01-01      24     -14     -2
# 2014-01-02      34      -1    -14
# 2014-01-03     -13     -17      9
# 2014-01-04      27      -1     33
# 2014-01-05      10      26    -16
# 2014-01-06     -20      36    -17
# 2014-01-07      20     -14     -1
# 2014-01-08      -7      10     27
# 2014-01-09      23      16      1
# 2014-01-10     -12      27     24
# 2014-01-11      20      11     18
# 2014-01-12      28      13     29
# 2014-01-13     -15      14     -7
# 2014-01-14      22      27     39
# 2014-01-15      39     -20     -3
# 2014-01-16      24      24    -17
# 2014-01-17      21      33     17
# 2014-01-18      -7      32     13
# 2014-01-19      29     -18     -2
# 2014-01-20      31      14     30
# 2014-01-21      35       8      5
# 2014-01-22       6      -3    -17
# 2014-01-23      -4      35      4
# 2014-01-24       0      33     18
# 2014-01-25     -13      -3     -4
# 2014-01-26      31     -17    -15
# 2014-01-27      35      24     37
# 2014-01-28      17      21     -1
# 2014-01-29      18      16      1
# 2014-01-30     -14      18     -5
# 2014-01-31      35       3     37
# 2014-02-01       6      26     -7
# 2014-02-02       8     -15     20
# 2014-02-03     -10      15     17
# 2014-02-04      21       3     35
# 2014-02-05      -9     -17     23
# 2014-02-06      14      23     35
# 2014-02-07      21      33      5
# 2014-02-08       4      11     29
# 2014-02-09      -6      -3     25
# 2014-02-10      -8      27     -2
# 2014-02-11      38       1     -6
# 2014-02-12      15     -14      4
# 2014-02-13      -3      14    -12
# 2014-02-14      17     -11      1
# 2014-02-15       2      17     27
# 2014-02-16      -5       0     16
# 2014-02-17      27       2     11
# 2014-02-18      22      15     -9
# 2014-02-19     -12      12     12
# 2014-02-20      26      18     38
# 2014-02-21       9     -16      8
# 2014-02-22     -17      29     13
# 2014-02-23     -12      11      8
# 2014-02-24      -4      20      8
# 2014-02-25       8      10      8
# 2014-02-26      29      20     36
# 2014-02-27      35      14    -19
# 2014-02-28      25      13      7

# %%
# range of rows and specific columns
df.ix[3:11, ['Boston','Shanghai']]
# Out:
#             Boston  Shanghai
# 2014-01-04      -1       -20
# 2014-01-05      26        33
# 2014-01-06      36        28
# 2014-01-07     -14        -2
# 2014-01-08      10       -17
# 2014-01-09      16        20
# 2014-01-10      27         7
# 2014-01-11      11        -2

# %% [markdown]
# ### 4.14 Practice using World Bank dataset

# %%
m = pd.read_csv('data/mortality.csv')

# %%
m
# Out:
#                        Country Name   1960   1961   1962   1963   1964   1965  \
# 0                             Aruba    NaN    NaN    NaN    NaN    NaN    NaN
# 1                           Andorra    NaN    NaN    NaN    NaN    NaN    NaN
# 2                       Afghanistan    NaN  352.5  346.9  341.8  336.8  331.6
# 3                            Angola    NaN    NaN    NaN    NaN    NaN    NaN
# 4                           Albania    NaN    NaN    NaN    NaN    NaN    NaN
# 5              United Arab Emirates  206.7  195.6  184.7  173.9  163.1  152.1
# 6                         Argentina    NaN    NaN    NaN    NaN    NaN    NaN
# 7                           Armenia    NaN    NaN    NaN    NaN    NaN    NaN
# 8                    American Samoa    NaN    NaN    NaN    NaN    NaN    NaN
# 9               Antigua and Barbuda    NaN    NaN    NaN    NaN    NaN    NaN
# 10                        Australia   24.8   24.3   23.7   23.2   22.7   22.4
# 11                          Austria   42.8   40.2   37.9   35.9   34.2   32.7
# 12                       Azerbaijan    NaN    NaN    NaN    NaN    NaN    NaN
# 13                          Burundi  245.4  245.0  244.7  244.2  243.7  243.7
# 14                          Belgium   33.9   32.4   31.2   30.0   28.9   27.9
# 15                            Benin  321.9  316.8  310.2  302.8  295.3  287.5
# 16                     Burkina Faso  344.9  340.1  335.8  332.1  328.8  325.1
# 17                       Bangladesh  262.4  255.3  248.4  241.9  235.9  231.1
# 18                         Bulgaria    NaN    NaN    NaN   46.5   45.7   45.0
# 19                          Bahrain  198.6  181.2  165.1  150.4  136.8  124.3
# 20                     Bahamas, The    NaN    NaN    NaN    NaN    NaN    NaN
# 21           Bosnia and Herzegovina    NaN    NaN    NaN    NaN    NaN    NaN
# 22                          Belarus    NaN    NaN    NaN    NaN    NaN    NaN
# 23                           Belize    NaN    NaN    NaN    NaN    NaN    NaN
# 24                          Bermuda    NaN    NaN    NaN    NaN    NaN    NaN
# 25                          Bolivia  294.1  287.1  280.1  273.5  267.1  260.5
# 26                           Brazil  172.4  167.1  161.7  156.9  152.5  148.5
# 27                         Barbados   86.4   80.5   75.3   70.6   66.4   62.6
# 28                Brunei Darussalam    NaN    NaN    NaN    NaN    NaN    NaN
# 29                           Bhutan    NaN    NaN    NaN    NaN    NaN    NaN
# ..                              ...    ...    ...    ...    ...    ...    ...
# 194        Turks and Caicos Islands    NaN    NaN    NaN    NaN    NaN    NaN
# 195                            Chad    NaN    NaN    NaN    NaN    NaN    NaN
# 196                            Togo  269.7  264.6  259.4  254.4  249.5  244.5
# 197                        Thailand  147.5  142.3  137.2  132.3  127.6  122.8
# 198                      Tajikistan    NaN    NaN    NaN    NaN    NaN    NaN
# 199                    Turkmenistan    NaN    NaN    NaN    NaN    NaN    NaN
# 200                     Timor-Leste    NaN    NaN    NaN    NaN    NaN    NaN
# 201                           Tonga    NaN    NaN    NaN   80.7   75.8   70.7
# 202             Trinidad and Tobago   68.4   66.1   64.1   62.1   60.3   58.7
# 203                         Tunisia    NaN  280.8  267.5  254.7  242.0  230.3
# 204                          Turkey  256.5  249.0  240.9  232.9  224.9  217.6
# 205                          Tuvalu    NaN    NaN    NaN    NaN    NaN    NaN
# 206                        Tanzania  241.6  239.6  237.1  234.7  231.9  228.7
# 207                          Uganda  224.4  219.5  214.1  209.1  204.0  198.8
# 208                         Ukraine    NaN    NaN    NaN    NaN    NaN    NaN
# 209                         Uruguay   64.8   62.7   60.5   58.4   56.8   56.5
# 210                   United States   30.1   29.5   28.9   28.3   27.7   27.1
# 211                      Uzbekistan    NaN    NaN    NaN    NaN    NaN    NaN
# 212  St. Vincent and the Grenadines    NaN    NaN    NaN    NaN    NaN    NaN
# 213                   Venezuela, RB   81.3   78.6   76.2   74.0   72.2   70.5
# 214           Virgin Islands (U.S.)    NaN    NaN    NaN    NaN    NaN    NaN
# 215                         Vietnam  119.8  114.5  109.7  105.0  100.9   97.4
# 216                         Vanuatu  152.4  148.0  143.9  139.3  134.8  130.4
# 217              West Bank and Gaza    NaN    NaN    NaN    NaN    NaN    NaN
# 218                           Samoa    NaN    NaN    NaN    NaN    NaN    NaN
# 219                     Yemen, Rep.    NaN  395.7  388.3  382.1  375.5  368.7
# 220                    South Africa    NaN    NaN    NaN    NaN    NaN    NaN
# 221                Congo, Dem. Rep.    NaN    NaN    NaN    NaN    NaN    NaN
# 222                          Zambia  205.8  202.0  198.3  195.1  192.4  190.0
# 223                        Zimbabwe  148.8  144.3  139.5  134.9  130.2  125.7
#
#       1966   1967   1968  ...    2004   2005   2006   2007   2008   2009  \
# 0      NaN    NaN    NaN  ...     NaN    NaN    NaN    NaN    NaN    NaN
# 1      NaN    NaN    NaN  ...     4.3    4.1    4.0    3.8    3.7    3.6
# 2    326.2  321.2  316.2  ...   121.0  117.7  114.5  111.5  108.8  106.2
# 3      NaN    NaN    NaN  ...   196.4  194.2  191.1  187.1  182.6  177.9
# 4      NaN    NaN    NaN  ...    23.3   22.2   21.2   20.3   19.5   18.8
# 5    141.2  130.4  119.7  ...    10.0    9.8    9.6    9.4    9.2    9.0
# 6      NaN    NaN    NaN  ...    17.8   17.1   16.5   15.9   15.5   15.2
# 7      NaN    NaN    NaN  ...    24.6   23.4   22.3   21.1   20.1   19.1
# 8      NaN    NaN    NaN  ...     NaN    NaN    NaN    NaN    NaN    NaN
# 9      NaN    NaN    NaN  ...    13.3   12.8   12.3   11.8   11.4   11.0
# 10    22.1   22.0   21.9  ...     5.8    5.6    5.5    5.3    5.2    5.1
# 11    31.5   30.5   29.8  ...     5.0    4.8    4.6    4.4    4.3    4.2
# 12     NaN    NaN    NaN  ...    54.6   51.2   48.1   45.3   42.7   40.5
# 13   243.8  244.1  244.5  ...   138.5  134.1  129.4  124.7  120.2  115.8
# 14    27.0   26.2   25.5  ...     5.0    4.9    4.8    4.7    4.6    4.5
# 15   281.1  275.5  271.1  ...   126.2  119.9  113.9  108.6  104.2  100.1
# 16   322.4  320.5  318.9  ...   167.5  159.6  150.7  141.1  131.6  122.6
# 17   227.1  224.3  222.3  ...    71.8   67.7   63.4   59.1   54.9   50.9
# 18    44.4   43.7   42.6  ...    17.0   15.9   15.0   14.3   13.7   13.3
# 19   112.8  102.1   92.3  ...    11.4   11.2   11.0   10.8   10.6   10.3
# 20     NaN    NaN   29.9  ...    18.2   18.3   18.3   18.2   18.1   17.9
# 21     NaN    NaN    NaN  ...     9.0    8.9    8.8    8.6    8.3    7.9
# 22     NaN    NaN    NaN  ...    10.2    9.4    8.7    7.9    7.3    6.6
# 23     NaN    NaN    NaN  ...    21.9   21.4   20.9   20.5   20.1   19.7
# 24     NaN    NaN    NaN  ...     NaN    NaN    NaN    NaN    NaN    NaN
# 25   253.9  247.3  240.8  ...    61.9   58.4   55.1   52.0   49.3   47.0
# 26   144.6  141.1  137.7  ...    24.8   23.1   21.5   20.0   18.6   17.4
# 27    59.2   56.1   53.2  ...    20.0   20.2   20.2   20.1   19.9   19.6
# 28     NaN    NaN    NaN  ...     8.9    8.7    8.6    8.5    8.3    8.2
# 29     NaN    NaN  287.5  ...    64.5   61.0   57.7   54.7   52.2   50.0
# ..     ...    ...    ...  ...     ...    ...    ...    ...    ...    ...
# 194    NaN    NaN    NaN  ...     NaN    NaN    NaN    NaN    NaN    NaN
# 195    NaN    NaN    NaN  ...   178.9  176.4  173.6  170.4  166.9  163.1
# 196  239.5  234.6  229.6  ...   113.7  111.8  109.9  107.9  105.9  103.6
# 197  118.1  113.5  108.7  ...    18.5   17.6   16.8   16.0   15.3   14.7
# 198    NaN    NaN    NaN  ...    77.0   74.1   71.6   69.2   66.8   64.4
# 199    NaN    NaN    NaN  ...    68.7   66.5   64.4   62.4   60.4   58.4
# 200    NaN    NaN    NaN  ...    84.7   79.9   75.4   71.3   67.7   64.5
# 201   65.9   61.6   57.5  ...    16.3   15.8   15.4   15.0   14.5   14.1
# 202   57.2   55.8   54.5  ...    25.7   25.1   24.5   23.9   23.3   22.5
# 203  218.9  208.2  197.5  ...    23.8   22.6   21.5   20.4   19.3   18.4
# 204  210.7  204.2  198.0  ...    26.2   23.9   21.8   19.8   18.2   16.9
# 205    NaN    NaN    NaN  ...    37.5   36.6   35.6   34.6   33.6   32.7
# 206  225.2  222.2  219.2  ...    97.3   90.1   83.5   77.2   71.4   66.4
# 207  194.0  189.6  185.6  ...   116.4  108.6  101.3   94.6   88.4   83.0
# 208    NaN    NaN    NaN  ...    15.1   14.5   14.0   13.5   13.0   12.4
# 209   57.8   59.5   59.2  ...    16.1   15.5   14.6   13.4   11.9   10.4
# 210   26.4   25.7   24.9  ...     8.0    8.0    7.9    7.8    7.7    7.6
# 211    NaN    NaN    NaN  ...    52.6   50.6   48.9   47.3   45.7   44.0
# 212    NaN    NaN    NaN  ...    22.6   22.9   23.2   23.5   23.7   23.9
# 213   69.0   67.5   66.0  ...    19.1   18.4   17.8   17.2   16.7   16.3
# 214    NaN    NaN    NaN  ...     NaN    NaN    NaN    NaN    NaN    NaN
# 215   94.0   91.1   88.6  ...    27.1   26.1   25.2   24.5   24.0   23.6
# 216  125.3  120.8  116.2  ...    22.6   22.0   21.4   20.8   20.2   19.7
# 217    NaN    NaN    NaN  ...    27.3   26.7   26.2   25.6   25.0   24.5
# 218    NaN    NaN    NaN  ...    19.5   19.1   18.9   18.7   18.5   18.3
# 219  360.6  351.7  342.1  ...    81.1   77.8   74.6   71.7   69.1   66.6
# 220    NaN    NaN    NaN  ...    80.3   79.1   76.5   72.5   69.0   63.1
# 221    NaN    NaN    NaN  ...   171.2  171.1  170.2  167.9  164.0  159.6
# 222  188.1  186.8  185.1  ...   134.9  127.0  120.4  114.6  109.4  104.4
# 223  121.6  118.1  115.2  ...    97.3   96.6   95.8   96.0   96.9   97.8
#
#       2010   2011   2012  2013
# 0      NaN    NaN    NaN   NaN
# 1      3.5    3.3    3.2   NaN
# 2    103.7  101.2   98.5   NaN
# 3    173.1  168.5  163.5   NaN
# 4     18.1   17.4   16.7   NaN
# 5      8.8    8.6    8.4   NaN
# 6     14.8   14.5   14.2   NaN
# 7     18.2   17.3   16.4   NaN
# 8      NaN    NaN    NaN   NaN
# 9     10.6   10.2    9.9   NaN
# 10     5.0    4.9    4.9   NaN
# 11     4.2    4.1    4.0   NaN
# 12    38.5   36.7   35.2   NaN
# 13   111.8  107.8  104.3   NaN
# 14     4.4    4.3    4.2   NaN
# 15    96.2   92.8   89.5   NaN
# 16   114.6  108.0  102.4   NaN
# 17    47.2   43.8   40.9   NaN
# 18    13.0   12.6   12.1   NaN
# 19    10.1    9.8    9.6   NaN
# 20    17.6   17.2   16.9   NaN
# 21     7.5    7.0    6.7   NaN
# 22     6.1    5.6    5.2   NaN
# 23    19.3   18.8   18.3   NaN
# 24     NaN    NaN    NaN   NaN
# 25    44.9   43.1   41.4   NaN
# 26    16.3   15.3   14.4   NaN
# 27    19.3   18.8   18.4   NaN
# 28     8.2    8.1    8.0   NaN
# 29    48.1   46.3   44.6   NaN
# ..     ...    ...    ...   ...
# 194    NaN    NaN    NaN   NaN
# 195  159.0  154.4  149.8   NaN
# 196  101.0   98.3   95.5   NaN
# 197   14.2   13.7   13.2   NaN
# 198   62.5   60.4   58.3   NaN
# 199   56.4   54.6   52.8   NaN
# 200   61.7   59.1   56.7   NaN
# 201   13.7   13.3   12.8   NaN
# 202   21.9   21.3   20.7   NaN
# 203   17.5   16.8   16.1   NaN
# 204   15.8   15.0   14.2   NaN
# 205   31.6   30.7   29.7   NaN
# 206   61.6   57.3   54.0   NaN
# 207   78.3   74.0   68.9   NaN
# 208   11.8   11.3   10.7   NaN
# 209    9.0    7.9    7.2   NaN
# 210    7.4    7.3    7.1   NaN
# 211   42.5   41.0   39.6   NaN
# 212   23.9   23.7   23.4   NaN
# 213   16.0   15.6   15.3   NaN
# 214    NaN    NaN    NaN   NaN
# 215   23.4   23.2   23.0   NaN
# 216   19.0   18.5   17.9   NaN
# 217   23.9   23.2   22.6   NaN
# 218   18.1   18.0   17.8   NaN
# 219   64.3   62.1   60.0   NaN
# 220   52.9   47.2   44.6   NaN
# 221  155.1  150.4  145.7   NaN
# 222  100.4   95.0   88.5   NaN
# 223   97.1   95.2   89.8   NaN
#
# [224 rows x 55 columns]

# %%
m = m.set_index('Country Name')

# %%
m.head()
# Out:
#               1960   1961   1962   1963   1964   1965   1966   1967   1968  \
# Country Name
# Aruba          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Andorra        NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan    NaN  352.5  346.9  341.8  336.8  331.6  326.2  321.2  316.2
# Angola         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania        NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#                1969  ...    2004   2005   2006   2007   2008   2009   2010  \
# Country Name         ...
# Aruba           NaN  ...     NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Andorra         NaN  ...     4.3    4.1    4.0    3.8    3.7    3.6    3.5
# Afghanistan   311.4  ...   121.0  117.7  114.5  111.5  108.8  106.2  103.7
# Angola          NaN  ...   196.4  194.2  191.1  187.1  182.6  177.9  173.1
# Albania         NaN  ...    23.3   22.2   21.2   20.3   19.5   18.8   18.1
#
#                2011   2012  2013
# Country Name
# Aruba           NaN    NaN   NaN
# Andorra         3.3    3.2   NaN
# Afghanistan   101.2   98.5   NaN
# Angola        168.5  163.5   NaN
# Albania        17.4   16.7   NaN
#
# [5 rows x 54 columns]

# %%
t = m.T

# %%
t.head()
# Out:
# Country Name  Aruba  Andorra  Afghanistan  Angola  Albania  \
# 1960            NaN      NaN          NaN     NaN      NaN
# 1961            NaN      NaN        352.5     NaN      NaN
# 1962            NaN      NaN        346.9     NaN      NaN
# 1963            NaN      NaN        341.8     NaN      NaN
# 1964            NaN      NaN        336.8     NaN      NaN
#
# Country Name  United Arab Emirates  Argentina  Armenia  American Samoa  \
# 1960                         206.7        NaN      NaN             NaN
# 1961                         195.6        NaN      NaN             NaN
# 1962                         184.7        NaN      NaN             NaN
# 1963                         173.9        NaN      NaN             NaN
# 1964                         163.1        NaN      NaN             NaN
#
# Country Name  Antigua and Barbuda    ...     Virgin Islands (U.S.)  Vietnam  \
# 1960                          NaN    ...                       NaN    119.8
# 1961                          NaN    ...                       NaN    114.5
# 1962                          NaN    ...                       NaN    109.7
# 1963                          NaN    ...                       NaN    105.0
# 1964                          NaN    ...                       NaN    100.9
#
# Country Name  Vanuatu  West Bank and Gaza  Samoa  Yemen, Rep.  South Africa  \
# 1960            152.4                 NaN    NaN          NaN           NaN
# 1961            148.0                 NaN    NaN        395.7           NaN
# 1962            143.9                 NaN    NaN        388.3           NaN
# 1963            139.3                 NaN    NaN        382.1           NaN
# 1964            134.8                 NaN    NaN        375.5           NaN
#
# Country Name  Congo, Dem. Rep.  Zambia  Zimbabwe
# 1960                       NaN   205.8     148.8
# 1961                       NaN   202.0     144.3
# 1962                       NaN   198.3     139.5
# 1963                       NaN   195.1     134.9
# 1964                       NaN   192.4     130.2
#
# [5 rows x 224 columns]

# %%
comparison = t[['Bangladesh','India','Rwanda','Uganda']]

# %%
comparison.tail()
# Out:
# Country Name  Bangladesh  India  Rwanda  Uganda
# 2009                50.9   63.8    69.4    83.0
# 2010                47.2   61.2    63.8    78.3
# 2011                43.8   58.6    58.9    74.0
# 2012                40.9   56.3    55.0    68.9
# 2013                 NaN    NaN     NaN     NaN

# %%
comparison.plot()
